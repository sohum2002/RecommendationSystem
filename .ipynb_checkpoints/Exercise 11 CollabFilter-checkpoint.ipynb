# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# #Pre Exercise
# This exercise is optional. You only have to hand in 10 exercises. If you hand in this one you may skip one of the earlier one.
#
# In the google doc sheet we have 41 restaurant and 44 people. There are about 1000 rating in total. We want to do collaborative filtering with 7 hidden features.
#
# https://docs.google.com/spreadsheets/d/143AcuFLKRLkz7yoKiEas0rABfuKPYCSlVKY1DUbFiBo/edit#gid=0

# %% [markdown]
# 1) What is the size of matrix F?

# %%
41 x 7
# Out:
#   File "<ipython-input-2-3e363afd5b09>", line 1
#     41 x 7
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 2) What is the size of matrix P?

# %%
44 x  7
# Out:
#   File "<ipython-input-3-cbcc51c7c7ec>", line 1
#     44 x  7
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 3) What should be the dimension of the Guess G? Write a numpy statement to calculate the Guess$G$ from $F$ and $P$.

# %%
guess = 44 (# of people) x 41 (# of restaurants)

np.dot(p,np.transpose(f))
# Out:
#   File "<ipython-input-4-cb082e20c871>", line 3
#     np.dot(p,np.transpose(f))
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# This code will help you do pre exercise. Try print names, restaurants, has_rating, rating to see what they are. rating and has_rating matrix use the convention that row=People, column=restaurant.

# %%
import StringIO
import csv
with open('rating.csv') as f:
    s = StringIO.StringIO(f.read()) 
    reader = csv.reader(s, delimiter=',')
    raw = [row for row in reader]

def get_names(raw):
    return raw[2][2:]

def get_restaurant(raw):
    restaurants = []
    for i in range(3, len(raw)):
        restaurants.append(raw[i][1])
    return restaurants

def get_rating(raw):
    
    names = get_names(raw)
    restaurants = get_restaurant(raw)
    #print restaurants
    name_offset = 2
    rests_offset = 3
    
    n_names = len(names)
    n_rests = len(restaurants)

    has_rating = np.zeros((n_names, n_rests))
    rating = np.zeros((n_names, n_rests))
    
    for ir in range(n_rests):
        this_row = raw[rests_offset + ir]
        #print ir, n_rests, len(raw), this_row[1]
        #print this_row
        for ip in range(n_names):
            #print ip, name_offset, len(this_row)
            this_cell =  this_row[name_offset + ip]
            hr = this_cell.isdigit()
            has_rating[ip, ir] = 1 if hr else 0
            if hr:
                rating[ip, ir] = int(this_cell)
    return names, restaurants, has_rating, rating

names, restaurants, has_rating, rating = get_rating(raw)
plt.matshow(rating, vmin=0, vmax=5)

# %% [markdown]
# 4) What is the dimension of rating matrix? AFTER you figure out, check it with rating.shape.

# %%
#rating matrix = 44 (people) x 41 (restaurants)

print rating.shape
# Out:
# (44, 41)

# %% [markdown]
# 5) What is the dimension of has_rating matrix? AFTER you figure out, check it with rating.shape.

# %%
# the same (44, 41)
print has_rating.shape
# Out:
# (44, 41)

# %% [markdown]
# 6) Suppose you have a the guess matrix G. How do you calculate HGR matrix? Write a numpy code for that

# %%
def hgr(f,p, rating, has_rating):
    cost1 = 0
    cost2 = 0
    guess = np.dot(p,np.transpose(f))
    
    for i in range(has_rating.shape[0]):
        for j in range(has_rating.shape[1]):
            cost1 += has_rating[i,j] * (guess[i,j] - rating[i,j])**2
            
f = np.ones((41,7))
p = np.ones((44,7))

hgr(f,p,rating,has_rating)

# %% [markdown]
# 7)The update rule for $P$ is
#
#
# $P = P - \eta\; dp$
#
# Write down the formula for dp. Then, write a numpy code to calculate dp.

# %%
def dp(f,p):
    return np.dot(hgr(f,p),f)

# %% [markdown]
# 8)The update rule for $F$ is
#
# $F = F - \eta\; df$
#
# Write down the formula for df. Then, write a numpy code to calculate df.

# %%
def df(f,p):
    return np.dot(np.transpose(hgr(f,p)),p)

# %% [markdown]
# 9) Write the numpy code to calculate the cost. (you may find np.sum useful)

# %% [markdown]
# #Exercise
# You have given CSV file for all the rating. Now your job is to figure out what is the next restaurant you should go next using collaborative filtering with gradient descent.
#
# The idea is to keep update matrix F and P with the update rule we find above many many times.
#
# Debugging this is quite a pain. One way to do it is to monitor the value of the costfunction making sure it is going in the right direction.
#
# If you are doing it right this should not be more than 50 lines.

# %%
class collabFilter:
    def __init__(self,names, restaurants, has_rating, rating):
        self.names = names
        self.restaurants = restaurants
        self.has_rating = has_rating
        self.rating = rating
    
    def compute(self):
        f = np.random.rand(41,7)
        p = np.random.rand(44,7)
        
        for i in xrange(1000000):
            hgr_out = self.hgr(f,p)
            dp = self.dp(hgr_out,f)
            df = self.df(hgr_out,p)
            
            p = p - (0.001 * dp)
            f = f - (0.001 * df)
        guess_rating = np.dot(p,np.transpose(f))
        return guess_rating
            
    def hgr(self,f,p):
        return has_rating * (np.dot(p,np.transpose(f)) - rating)
        
    def dp(self,cost1,f):
        return np.dot(cost1,f)

    def df(self,cost1,p):
        return np.dot(np.transpose(cost1),p)
    
cf = collabFilter(names, restaurants, has_rating, rating)

G = cf.compute()
# Out:
# ['Mai-tok-mai-tak', 'Puttharaksa', 'Big Mamma', 'Seefah', 'Music Square', 'Mamma Mia', 'Srijan', 'Steak House', 'Anya', 'Chicky Chic', 'Loong Nuad', 'Nong Na', 'Shabu Nangnai', 'Buri-yummy', 'Gin-na', 'Fong-nom', 'Fresh box', 'Buta grill', 'Lodiham', 'Kao-pun', 'Sutharos', 'Hua-seng-hong', 'Jok at 3 AM', 'RIT', 'Hong nung len', 'slum bar', 'Ban-nam', 'Mango Bar', 'Sri suwan', 'Herb Garden', 'Best Bar', 'Princess Cafe', 'Hachi Ban', 'Vietnam Hut', 'Chi-see', 'J-Class', 'Bon chon', 'Sunrise Taco', 'Beach Bar', 'Brew & Bev', 'Bake & Bite']

# %% [markdown]
# #Debugging Tip
# To compare your guess rating(G*has_rating) and the actual rating graphically use
#
# plt.matshow(rating, vmin=0, vmax=5)
#
#  if they look almost the same then your algorithm is doing the right thing

# %%
# plt.matshow(rating, vmin=0, vmax=5)
# plt.figure()
# plt.matshow(G*has_rating, vmin=0, vmax=5)

# %% [markdown]
# #Once you have F and P and guess matrix.
# I wrote this so that visualizing your result is easier.

# %%
from IPython.display import HTML

class TableCell:
    
    def __init__(self, text, tc=None, color=None):
        self.text = text
        self.tc = tc
        self.color = color
    
    def to_html(self):
        return '<td>%s</td>'%self.text
    
def maketable(rating, has_rating, guess, restaurants, names):
    n_rests = len(restaurants)
    n_names = len(names)
    tab = np.empty((n_rests+1, n_names+1),dtype='object')
    #print tab.shape

    for irest in range(n_rests):
        tab[irest+1,0] = restaurants[irest]

    for iname in range(n_names):
        tab[0,iname+1] = names[iname]

    for irest in range(n_rests):
        for iname in range(n_names):
            if not has_rating[iname, irest]:
                tab[irest+1, iname+1] = TableCell('<span style="color:red">%3.2f</span>'%(guess[iname, irest]))
            else:
                tab[irest+1, iname+1] = TableCell('<span style="color:blue">%3.2f</span><span style="color:red">(%3.2f)</span>'%(rating[iname, irest], guess[iname, irest]))
    #now convert tab array to nice html table
    nrow, ncol = tab.shape
    t = []
    t.append('<table>')
    for irow in range(nrow):
        t.append('<tr>')
        for icol in range(ncol):
            cell = tab[irow,icol]
            if cell is not None:
                if isinstance(cell,TableCell):
                    t.append(tab[irow, icol].to_html())
                else:
                    t.append('<td>')
                    t.append(tab[irow, icol])
                    t.append('</td>')
            else:
                t.append('<td></td>')
        t.append('</tr>')  
    t.append('</table>')
    print t[138]
    return '\n'.join(t)

# %%
# call it like this

HTML(maketable(rating, has_rating, G, restaurants, names))
# Out:
# Mai-tok-mai-tak
# <table>
# <tr>
# <td></td>
# <td>
# Piti
# </td>
# <td>
# Meena
# </td>
# <td>
# Pitoon
# </td>
# <td>
# Sohum
# </td>
# <td>
# Sam
# </td>
# <td>
# Keng
# </td>
# <td>
# O
# </td>
# <td>
# Yok
# </td>
# <td>
# Kitty
# </td>
# <td>
# Time
# </td>
# <td>
# Robroo
# </td>
# <td>
# Peem
# </td>
# <td>
# Chanon
# </td>
# <td>
# Ohm
# </td>
# <td>
# Sun
# </td>
# <td>
# Tii
# </td>
# <td>
# Tow
# </td>
# <td>
# John
# </td>
# <td>
# Mint
# </td>
# <td>
# Opal
# </td>
# <td>
# Kelly
# </td>
# <td>
# Jay
# </td>
# <td>
# Sharik
# </td>
# <td>
# Ou
# </td>
# <td>
# PJ
# </td>
# <td>
# Punawit
# </td>
# <td>
# Martin
# </td>
# <td>
# Ploy
# </td>
# <td>
# Majeed
# </td>
# <td>
# Bossy
# </td>
# <td>
# Sea
# </td>
# <td>
# Pan
# </td>
# <td>
# Ice
# </td>
# <td>
# Karn
# </td>
# <td>
# May
# </td>
# <td>
# Rin
# </td>
# <td>
# Peter
# </td>
# <td>
# Ham
# </td>
# <td>
# Benz
# </td>
# <td>
# Billy
# </td>
# <td>
# Kanat
# </td>
# <td>
# Sam
# </td>
# <td>
# Boss
# </td>
# <td>
# Best
# </td>
# </tr>
# <tr>
# <td>
# Mai-tok-mai-tak
# </td>
# <td><span style="color:red">6.51</span></td>
# <td><span style="color:red">-8.01</span></td>
# <td><span style="color:blue">2.00</span><span style="color:red">(1.81)</span></td>
# <td><span style="color:red">2.94</span></td>
# <td><span style="color:red">-0.26</span></td>
# <td><span style="color:blue">2.00</span><span style="color:red">(2.27)</span></td>
# <td><span style="color:blue">2.00</span><span style="color:red">(2.44)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.78)</span></td>
# <td><span style="color:red">5.04</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.64)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.84)</span></td>
# <td><span style="color:blue">5.00</span><span style="color:red">(5.09)</span></td>
# <td><span style="color:red">1.96</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.95)</span></td>
# <td><span style="color:blue">2.00</span><span style="color:red">(2.51)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.90)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.02)</span></td>
# <td><span style="color:red">3.50</span></td>
# <td><span style="color:blue">2.00</span><span style="color:red">(2.25)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.00)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.90)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.33)</span></td>
# <td><span style="color:red">0.84</span></td>
# <td><span style="color:blue">2.00</span><span style="color:red">(2.50)</span></td>
# <td><span style="color:red">-11.64</span></td>
# <td><span style="color:red">5.02</span></td>
# <td><span style="color:red">1.91</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(2.57)</span></td>
# <td><span style="color:red">-9.68</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.41)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.98)</span></td>
# <td><span style="color:red">-3.77</span></td>
# <td><span style="color:red">4.03</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.84)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.83)</span></td>
# <td><span style="color:red">-7.46</span></td>
# <td><span style="color:red">7.90</span></td>
# <td><span style="color:red">2.30</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.72)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.77)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.68)</span></td>
# <td><span style="color:red">1.85</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(4.17)</span></td>
# <td><span style="color:blue">5.00</span><span style="color:red">(4.63)</span></td>
# </tr>
# <tr>
# <td>
# Puttharaksa
# </td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.78)</span></td>
# <td><span style="color:red">1.87</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.96)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.86)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(4.14)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.10)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.61)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.71)</span></td>
# <td><span style="color:red">3.73</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.26)</span></td>
# <td><span style="color:red">2.11</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(4.12)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.13)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(4.26)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.93)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.93)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.67)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.51)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.14)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.15)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.39)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.09)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.46)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.86)</span></td>
# <td><span style="color:red">-2.89</span></td>
# <td><span style="color:red">2.83</span></td>
# <td><span style="color:red">3.45</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.75)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.92)</span></td>
# <td><span style="color:red">2.59</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.62)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.98)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.87)</span></td>
# <td><span style="color:red">3.46</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(3.61)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(3.00)</span></td>
# <td><span style="color:red">3.28</span></td>
# <td><span style="color:red">3.80</span></td>
# <td><span style="color:blue">1.00</span><span style="color:red">(2.23)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(4.13)</span></td>
# <td><span style="color:blue">3.00</span><span style="color:red">(2.79)</span></td>
# <td><span style="color:red">2.76</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(4.09)</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(4.09)</span></td>
# </tr>
# <tr>
# <td>
# Big Mamma
# </td>
# <td><span style="color:red">-14.62</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(4.00)</span></td>
# <td><span style="color:red">-10.76</span></td>
# <td><span style="color:blue">5.00</span><span style="color:red">(5.01)</span></td>
# <td><span style="color:blue">5.00</span><span style="color:red">(4.98)</span></td>
# <td><span style="color:red">13.07</span></td>
# <td><span style="color:red">5.85</span></td>
# <td><span style="color:red">15.10</span></td>
# <td><span style="color:blue">4.00</span><span style="color:red">(4.00)</span></td>
# <td><span style="color:red">6.92</span></td>
# <td><span style="color:red">10.76</span></td>
# <td><span style="color:red">-8.04</span></td>
# <td><span style="color:red">3.57</span></td>
# <td><span style="color:red">-31.85</span></td>
# <td><span style="color:red">7.54</span></td>
# <td><span style="color:red">-6.45</span></td>
# <td><span style="color:red">17.70</span></td>
# <td><span style="color:red">
